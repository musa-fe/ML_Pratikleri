# %% [markdown]
# Neden Kullanılır?
#
#
# *   Görselleştirme için
# *   Gürültüyü azaltmak
# *   Eğitim süresini kısaltmak
# *   Aşırı öğrenmeyi önlemek

# %%
from sklearn.datasets import load_iris
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt


iris = load_iris()
X = iris.data
y = iris.target

# PCA uygulayarak 4 boyutlu veriyi 2 boyuta indir
pca = PCA(n_components=2)  # 2 adet temel bileşen (principal component)
X_pca = pca.fit_transform(X)


plt.figure()
for i in range(len(iris.target_names)):
    plt.scatter(X_pca[y == i, 0], X_pca[y == i, 1], label=iris.target_names[i])

plt.xlabel("PC1")  # 1. temel bileşen
plt.ylabel("PC2")  # 2. temel bileşen
plt.title("PCA of Iris Dataset")
plt.legend()
plt.show()
